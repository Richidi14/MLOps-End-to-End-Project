# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd

# %%
from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, CatTargetDriftTab
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection

# %%
Data_url = 'https://raw.githubusercontent.com/tomsharp/SVR/refs/heads/master/data/Boston%20Housing%20Prices.csv'
boston_data= pd.read_csv(Data_url)

# %%
boston_data
# Out:
#            town  tract  longitude   latitude    crime  residential  \
# 0        Nahant   2011 -70.955002  42.255001  0.00632         18.0
# 1    Swampscott   2021 -70.949997  42.287498  0.02731          0.0
# 2    Swampscott   2022 -70.935997  42.283001  0.02729          0.0
# 3    Marblehead   2031 -70.928001  42.292999  0.03237          0.0
# 4    Marblehead   2032 -70.921997  42.298000  0.06905          0.0
# ..          ...    ...        ...        ...      ...          ...
# 501    Winthrop   1801 -70.986000  42.231201  0.06263          0.0
# 502    Winthrop   1802 -70.990997  42.227501  0.04527          0.0
# 503    Winthrop   1803 -70.994797  42.226002  0.06076          0.0
# 504    Winthrop   1804 -70.987503  42.223999  0.10959          0.0
# 505    Winthrop   1805 -70.982498  42.221001  0.04741          0.0
#
#      industrial river    nox  rooms      older  distance  highway  tax  \
# 0          2.31    no  0.538  6.575  65.199997    4.0900        1  296
# ...

# %%
boston_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   town         506 non-null    object
#  1   tract        506 non-null    int64
#  2   longitude    506 non-null    float64
#  3   latitude     506 non-null    float64
#  4   crime        506 non-null    float64
#  5   residential  506 non-null    float64
#  6   industrial   506 non-null    float64
#  7   river        506 non-null    object
#  8   nox          506 non-null    float64
#  9   rooms        506 non-null    float64
#  10  older        506 non-null    float64
#  11  distance     506 non-null    float64
#  12  highway      506 non-null    int64
#  13  tax          506 non-null    int64
#  14  ptratio      506 non-null    float64
#  15  lstat        506 non-null    float64
#  16  cmedv        506 non-null    float64
# dtypes: float64(12), int64(3), object(2)
# ...

# %%
# Data Drift Dashboard 
boston_data.shape
# Out:
# (506, 17)

# %%
boston_data.drop(columns='town', axis= 1, inplace=True)

# %%
Training = boston_data[:200] #training Sample

# %%
reference= boston_data[200:] #reference sample

# %%
boston_DDD= Dashboard(tabs=[DataDriftTab()])

# %%
boston_DDD.calculate(Training, reference)

# %%
boston_DDD.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
# ...

# %%
boston_DDD.save('boston_data_drift_report.html')
